# %%
import pandas as pd
df=pd.read_csv("/Users/sindhupathipati/Downloads/Crab Molt Data.csv")
df
# Out:
#      Post-molt  Pre-molt Location
# 0        127.7     113.6    Field
# 1        133.2     118.1    Field
# 2        135.3     119.9    Field
# 3        143.3     126.2    Field
# 4        139.3     126.7    Field
# ..         ...       ...      ...
# 467      150.3     135.9      Lab
# 468      151.2     135.6      Lab
# 469      143.5     129.6      Lab
# 470      148.3     134.1      Lab
# 471      129.2     114.4      Lab
#
# [472 rows x 3 columns]

# %%
import pandas as pd
df=pd.read_csv("/Users/sindhupathipati/Downloads/Crab Molt Data.csv")

max_value_premolt_field =df[df['Location'] == 'Field']['Pre-molt'].max()
min_value_premolt_field =df[df['Location'] == 'Field']['Pre-molt'].min()
print(f'Maximum values of Pre-molt for Field data:\n{max_value_premolt_field} ')
print(f'Minimum values of Pre-molt for Field data :\n{min_value_premolt_field} ')

mean_Pre = df[df['Location'] == 'Field']['Pre-molt'].mean()
print(f'\nPre-molt mean Field: {mean_Pre} ')

median_Pre = df[df['Location'] == 'Field']['Pre-molt'].median()
print(f'\nPre-molt Median Field: {median_Pre}')

std_Pre_field= df[df['Location'] == 'Field']['Pre-molt'].std()
print(f'Pre-molt Standard Deviation: {std_Pre_field} ')

skew_Pre_field = df[df['Location'] == 'Field']['Pre-molt'].skew()
print(f'Pre-molt skewness: {skew_Pre_field}')

kurtosis_Pre =df[df['Location'] == 'Field']['Pre-molt'].kurtosis()
print(f'Pre-molt kurtosis for Field data: {kurtosis_Pre}')
# Out:
# Maximum values of Pre-molt for Field data:
# 153.9
# Minimum values of Pre-molt for Field data :
# 113.6
#
# Pre-molt mean Field: 139.00900900900902
#
# Pre-molt Median Field: 140.1
# Pre-molt Standard Deviation: 7.251151000164789
# Pre-molt skewness: -1.1261509778983905
# Pre-molt kurtosis for Field data: 1.899505679507722

# %%
import pandas as pd
df=pd.read_csv("/Users/sindhupathipati/Downloads/Crab Molt Data.csv")

max_value_postmolt_field =df[df['Location'] == 'Field']['Post-molt'].max()
min_value_postmolt_field =df[df['Location'] == 'Field']['Post-molt'].min()

print(f'Maximum values of Post-molt for Field data:\n {max_value_postmolt_field}')
print(f'Minimum values of Post-molt for Field data :\n{min_value_postmolt_field}')

mean_Post = df[df['Location'] == 'Field']['Post-molt'].mean()
print(f'Post-molt mean Field: {mean_Post} ')

mean_Post = df[df['Location'] == 'Field']['Post-molt'].median()
print(f'Post-molt Median Field: {mean_Post} ')

std_Post_field =df[df['Location'] == 'Field']['Post-molt'].std()
print(f'Post-molt Standard Deviation: {std_Post_field} ')

skew_Post_field =df[df['Location'] == 'Field']['Post-molt'].skew()
print(f'Post-molt skewness: {skew_Post_field} ')

kurtosis_Post =df[df['Location'] == 'Field']['Post-molt'].kurtosis()
print(f'Post-molt kurtosis for Field data: {kurtosis_Post} ')
# Out:
# Maximum values of Post-molt for Field data:
#  166.5
# Minimum values of Post-molt for Field data :
# 127.7
# Post-molt mean Field: 152.96396396396398
# Post-molt Median Field: 154.0
# Post-molt Standard Deviation: 6.7199674348885265
# Post-molt skewness: -1.1344522756613946
# Post-molt kurtosis for Field data: 2.4010786773002724

# %%
import pandas as pd
df=pd.read_csv("/Users/sindhupathipati/Downloads/Crab Molt Data.csv")

max_value_postmolt_lab =df[df['Location'] == 'Lab']['Post-molt'].max()
min_value_postmolt_lab =df[df['Location'] == 'Lab']['Post-molt'].min()

print(f'Maximum values of Post-molt for Lab data:\n {max_value_postmolt_lab}')
print(f'Minimum values of Post-molt for Lab data:\n {min_value_postmolt_lab}')

mean_Post = df[df['Location'] == 'Lab']['Post-molt'].mean()
print(f'Post-molt mean Lab: {mean_Post} ')

mean_Post = df[df['Location'] == 'Lab']['Post-molt'].median()
print(f'Post-molt Median Lab: {mean_Post} ')

std_Post_lab =df[df['Location'] == 'Lab']['Post-molt'].std()
print(f'Post-molt Standard Deviation: {std_Post_lab} ')


skew_Post_lab =df[df['Location'] == 'Lab']['Post-molt'].skew()
print(f'Post-molt skewness: {skew_Post_lab} ')


kurtosis_Post =df[df['Location'] == 'Lab']['Post-molt'].kurtosis()
print(f'Post-molt kurtosis for Lab data: {kurtosis_Post} ')
# Out:
# Maximum values of Post-molt for Lab data:
#  166.8
# Minimum values of Post-molt for Lab data:
#  38.8
# Post-molt mean Lab: 141.10997229916896
# Post-molt Median Lab: 143.7
# Post-molt Standard Deviation: 15.280779875724328
# Post-molt skewness: -2.2976727187727493
# Post-molt kurtosis for Lab data: 9.591102985588982

# %%
import pandas as pd
df=pd.read_csv("/Users/sindhupathipati/Downloads/Crab Molt Data.csv")

max_value_premolt_lab =df[df['Location'] == 'Lab']['Pre-molt'].max()
min_value_premolt_lab =df[df['Location'] == 'Lab']['Pre-molt'].min()


print(f'Maximum values of Pre-molt for Lab data:\n{max_value_premolt_lab} ')
print(f'Minimum values of Pre-molt for Lab data:\n{min_value_premolt_lab} ')

mean_Pre = df[df['Location'] == 'Lab']['Pre-molt'].mean()
print(f'Pre-molt mean for Lab: {mean_Pre}')

mean_Pre = df[df['Location'] == 'Lab']['Pre-molt'].median()
print(f'Pre-molt Medain for Lab: {mean_Pre}  ')

std_Pre_lab= df[df['Location'] == 'Lab']['Pre-molt'].std()
print(f'Pre-molt Standard Deviation: {std_Pre_lab} ')

skew_Pre_lab = df[df['Location'] == 'Lab']['Pre-molt'].skew()
print(f'Pre-molt skewness: {skew_Pre_lab}  ')

kurtosis_Pre =df[df['Location'] == 'Lab']['Pre-molt'].kurtosis()
print(f'Pre-molt kurtosis for Lab data: {kurtosis_Pre}')
# Out:
# Maximum values of Pre-molt for Lab data:
# 155.1
# Minimum values of Pre-molt for Lab data:
# 31.1
# Pre-molt mean for Lab: 126.19944598337948
# Pre-molt Medain for Lab: 128.9
# Pre-molt Standard Deviation: 16.568779198741762
# Pre-molt skewness: -1.89682755576862
# Pre-molt kurtosis for Lab data: 6.125483832351996

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# Q-Q plot for normality
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
stats.probplot(df[df['Location'] == 'Lab']['Pre-molt'], dist="norm", plot=axes[0])
axes[0].set_title('Pre-Molt Size Q-Q Plot for Lab data')

stats.probplot(df[df['Location'] == 'Lab']['Post-molt'], dist="norm", plot=axes[1])
axes[1].set_title('Post-Molt Size Q-Q Plot for Lab data')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

fig, axes = plt.subplots(1, 2, figsize=(12, 6))
stats.probplot(df[df['Location'] == 'Lab']['Pre-molt'], dist="norm", plot=axes[0])
axes[0].set_title('Pre-Molt Size Q-Q Plot for Field data')

stats.probplot(df[df['Location'] == 'Lab']['Post-molt'], dist="norm", plot=axes[1])
axes[1].set_title('Post-Molt Size Q-Q Plot for Field data')

plt.show()

# %%
import pandas as pd
from scipy.stats import anderson, kstest, cramervonmises, shapiro

# Assuming filtered_df_field is your DataFrame with the 'Pre-molt' column
pre_molt_sizes = df[df['Location'] == 'Field']['Pre-molt']

# Anderson-Darling Test
ad_result = anderson(pre_molt_sizes)
print(f"Anderson-Darling Test Statistic: {ad_result.statistic}")
print(f"Critical Values: {ad_result.critical_values}")
print(f"Significance Levels: {ad_result.significance_level}")

# Kolmogorov-Smirnov Test
ks_result = kstest(pre_molt_sizes, 'norm')
print("\nKolmogorov-Smirnov Test Statistic:", ks_result.statistic)
print("Kolmogorov-Smirnov P-Value:", ks_result.pvalue)

# Cramer-von Mises Test
cvm_result = cramervonmises(pre_molt_sizes, 'norm')
print(f"\nCramer-von Mises Test Statistic: {cvm_result.statistic}")
print(f"Cramer-von Mises P-Value: {cvm_result.pvalue}")

# Shapiro-Wilk Test
sw_result = shapiro(pre_molt_sizes)
print("\nShapiro-Wilk Test Statistic:", sw_result.statistic)
print(f"Shapiro-Wilk P-Value: {sw_result.pvalue}")
# Out:
# Anderson-Darling Test Statistic: 1.899067442726178
# Critical Values: [0.557 0.634 0.761 0.888 1.056]
# Significance Levels: [15.  10.   5.   2.5  1. ]
#
# Kolmogorov-Smirnov Test Statistic: 1.0
# Kolmogorov-Smirnov P-Value: 0.0
#
# Cramer-von Mises Test Statistic: 37.00000000000001
# Cramer-von Mises P-Value: 0
#
# Shapiro-Wilk Test Statistic: 0.9313224935164635
# Shapiro-Wilk P-Value: 2.387389571369495e-05

# %%
import pandas as pd
from scipy.stats import anderson, kstest, cramervonmises, shapiro

# Define functions for each test

def anderson_darling_test(data):
    result = anderson(data)
    print(f"Anderson-Darling Test Statistic: {result.statistic}")
    print(f"Anderson-Darling Critical Values: {result.critical_values}")
    print(f"Anderson-Darling Significance Levels: {result.significance_level}\n")

def kolmogorov_smirnov_test(data):
    statistic, p_value = kstest(data, 'norm')
    print(f"Kolmogorov-Smirnov Test Statistic: {statistic}")
    print(f"Kolmogorov-Smirnov P-Value: {p_value}\n")

def cramervonmises_test(data):
    result = cramervonmises(data, 'norm')
    print(f"Cramer-von Mises Test Statistic: {result.statistic}")
    print(f"Cramer-von Mises P-Value: {result.pvalue}\n")

def shapiro_wilk_test(data):
    statistic, p_value = shapiro(data)
    print(f"Shapiro-Wilk Test Statistic: {statistic}")
    print(f"Shapiro-Wilk P-Value: {p_value}\n")

# Load data and extract the 'Pre-molt' column
pre_molt_sizes_lab =df[df['Location'] == 'Lab']['Pre-molt']

# Run all tests
anderson_darling_test(pre_molt_sizes_lab)
kolmogorov_smirnov_test(pre_molt_sizes_lab)
cramervonmises_test(pre_molt_sizes_lab)
shapiro_wilk_test(pre_molt_sizes_lab)
# Out:
# Anderson-Darling Test Statistic: 9.255798135902864
# Anderson-Darling Critical Values: [0.57  0.649 0.779 0.908 1.08 ]
# Anderson-Darling Significance Levels: [15.  10.   5.   2.5  1. ]
#
# Kolmogorov-Smirnov Test Statistic: 1.0
# Kolmogorov-Smirnov P-Value: 0.0
#
# Cramer-von Mises Test Statistic: 120.33333333333333
# Cramer-von Mises P-Value: 0
#
# Shapiro-Wilk Test Statistic: 0.8615104215794119
# Shapiro-Wilk P-Value: 2.1427046241938793e-17

# %%
import pandas as pd
from scipy.stats import anderson, kstest, cramervonmises, shapiro

# Extract the 'Post-molt' column
post_molt_sizes_field = df[df['Location'] == 'Field']['Post-molt']

# Anderson-Darling Test
anderson_result = anderson(post_molt_sizes_field)
print(f"Anderson-Darling Test Statistic: {anderson_result.statistic}")
print(f"Anderson-Darling Critical Values: {anderson_result.critical_values}")
print(f"Anderson-Darling Significance Levels: {anderson_result.significance_level}\n")

# Kolmogorov-Smirnov Test
ks_statistic, ks_p_value = kstest(post_molt_sizes_field, 'norm')
print(f"Kolmogorov-Smirnov Test Statistic: {ks_statistic}")
print(f"Kolmogorov-Smirnov P-Value: {ks_p_value}\n")

# Cramer-von Mises Test
cvm_result = cramervonmises(post_molt_sizes_field, 'norm')
print(f"Cramer-von Mises Test Statistic: {cvm_result.statistic}")
print(f"Cramer-von Mises P-Value: {cvm_result.pvalue}\n")

# Shapiro-Wilk Test
shapiro_statistic, shapiro_p_value = shapiro(post_molt_sizes_field)
print(f"Shapiro-Wilk Test Statistic: {shapiro_statistic}")
print(f"Shapiro-Wilk P-Value: {shapiro_p_value}")
# Out:
# Anderson-Darling Test Statistic: 1.667443334267034
# Anderson-Darling Critical Values: [0.557 0.634 0.761 0.888 1.056]
# Anderson-Darling Significance Levels: [15.  10.   5.   2.5  1. ]
#
# Kolmogorov-Smirnov Test Statistic: 1.0
# Kolmogorov-Smirnov P-Value: 0.0
#
# Cramer-von Mises Test Statistic: 37.00000000000001
# Cramer-von Mises P-Value: 0
#
# Shapiro-Wilk Test Statistic: 0.9334666723036671
# Shapiro-Wilk P-Value: 3.2262416356510226e-05

# %%
import pandas as pd
from scipy.stats import anderson, kstest, cramervonmises, shapiro

# Extracting 'Post-molt' column
post_molt_sizes_lab = df[df['Location'] == 'Lab']['Post-molt']

# Anderson-Darling Test
anderson_result = anderson(post_molt_sizes_lab)
print(f"Anderson-Darling Test Statistic: {anderson_result.statistic}")
print(f"Anderson-Darling Critical Values: {anderson_result.critical_values}")
print(f"Anderson-Darling Significance Levels: {anderson_result.significance_level}\n")

# Kolmogorov-Smirnov Test
ks_statistic, ks_p_value = kstest(post_molt_sizes_lab, 'norm')
print(f"Kolmogorov-Smirnov Test Statistic: {ks_statistic}")
print(f"Kolmogorov-Smirnov P-Value: {ks_p_value}\n")

# Cramer-von Mises Test
cvm_result = cramervonmises(post_molt_sizes_lab, 'norm')
print(f"Cramer-von Mises Test Statistic: {cvm_result.statistic}")
print(f"Cramer-von Mises P-Value: {cvm_result.pvalue}\n")

# Shapiro-Wilk Test
shapiro_statistic, shapiro_p_value = shapiro(post_molt_sizes_lab)
print(f"Shapiro-Wilk Test Statistic: {shapiro_statistic}")
print(f"Shapiro-Wilk P-Value: {shapiro_p_value}")
# Out:
# Anderson-Darling Test Statistic: 10.758090987208561
# Anderson-Darling Critical Values: [0.57  0.649 0.779 0.908 1.08 ]
# Anderson-Darling Significance Levels: [15.  10.   5.   2.5  1. ]
#
# Kolmogorov-Smirnov Test Statistic: 1.0
# Kolmogorov-Smirnov P-Value: 0.0
#
# Cramer-von Mises Test Statistic: 120.33333333333333
# Cramer-von Mises P-Value: 0
#
# Shapiro-Wilk Test Statistic: 0.8333079256419074
# Shapiro-Wilk P-Value: 4.628040046363319e-19

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a scatterplot of pre-molt sizes versus post-molt sizes
plt.figure(figsize=(8, 6))
plt.scatter(df[df['Location'] == 'Lab']['Post-molt'], df[df['Location'] == 'Lab']['Pre-molt'], color='blue', alpha=0.6)

# Adding labels and title
plt.title('Scatterplot of Pre-Molt Sizes vs Post-Molt Sizes for Lab data', fontsize=14)
plt.xlabel('Post-Molt Size', fontsize=12)
plt.ylabel('Pre-Molt Size', fontsize=12)

# Show the plot
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Create a scatterplot of pre-molt sizes versus post-molt sizes
plt.figure(figsize=(8, 6))
plt.scatter(df[df['Location'] == 'Field']['Post-molt'], df[df['Location'] == 'Field']['Pre-molt'], color='blue', alpha=0.6)

# Adding labels and title
plt.title('Scatterplot of Pre-Molt Sizes vs Post-Molt Sizes for Field data', fontsize=14)
plt.xlabel('Post-Molt Size', fontsize=12)
plt.ylabel('Pre-Molt Size', fontsize=12)

# Show the plot
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

group_A = df[df['Location'] == 'Lab']['Post-molt']
group_B = df[df['Location'] == 'Lab']['Pre-molt']
# Creating a comparison plot of smooth histograms
plt.figure(figsize=(10, 6))

# Plot smooth histograms 
sns.histplot(group_A, kde=True, label='Post-molt', color='red')
sns.histplot(group_B, kde=True, label='Pre-molt', color='green')

# Add labels and legend
plt.title('Comparison of Smooth Histograms for post-molt and pre-molt of Lab')
plt.xlabel('Values')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

group_A = df[df['Location'] == 'Field']['Post-molt']
group_B = df[df['Location'] == 'Field']['Pre-molt']

# Creating a comparison plot of smooth histograms for field data
plt.figure(figsize=(10, 6))

# Plot smooth histograms 
sns.histplot(group_A, kde=True, label='pre-molt', color='red')
sns.histplot(group_B, kde=True, label='Post-molt', color='green')

# Add labels and legend
plt.title("Comparison of Smooth Histograms for pre-molt and post-molt of Field")
plt.xlabel('Sizes')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

post_field = df[df['Location'] == 'Field']['Post-molt']
pre_field = df[df['Location'] == 'Field']['Pre-molt']

# Perform Linear Least Squares for treatment data
slope, intercept, r_value, p_value, std_err = linregress(post_field, pre_field)

# Calculate predicted values using the linear model
predicted_pre = slope * post_field + intercept

# Calculate residuals
residuals_f = pre_field-predicted_pre

# Create a figure for the plots
plt.figure(figsize=(12, 6))

# Scatterplot with regression line
plt.subplot(1, 2, 1)
plt.scatter(post_field, pre_field, color='blue', alpha=0.7, label='Data')
plt.plot(post_field, predicted_pre, color='red', label='Linear Regression')

# Add labels and title
plt.title('Linear Least Squares: pre-molt vs post-molt for field data')
plt.xlabel('post-molt')
plt.ylabel('pre-molt')
plt.legend()

# Residual plot
plt.subplot(1, 2, 2)
plt.scatter(predicted_pre, residuals_f, color='green', alpha=0.7)

# Add a horizontal line for zero residuals
plt.axhline(0, color='black', linestyle='--', label='Zero Residuals Line')

# Add labels and title
plt.title('Residuals Plot')
plt.xlabel('Predicted pre molt')
plt.ylabel('Residuals')
plt.legend()

# Show the plots
plt.tight_layout()
plt.show()

# Print Pearson's R-squared value
r_squared = r_value**2
print(f"Pearson's R-squared value: {r_squared}")
# Out:
# Pearson's R-squared value: 0.9327747000533485

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

post_lab = df[df['Location'] == 'Lab']['Post-molt']
pre_lab = df[df['Location'] == 'Lab']['Pre-molt']

# Perform Linear Least Squares for treatment data
slope, intercept, r_value, p_value, std_err = linregress(post_lab, pre_lab)

# Calculate predicted values using the linear model
predicted_pre = slope * post_lab + intercept

# Calculate residuals
residuals_l = pre_lab-predicted_pre

# Create a figure for the plots
plt.figure(figsize=(12, 6))

# Scatterplot with regression line
plt.subplot(1, 2, 1)
plt.scatter(post_lab, pre_lab, color='blue', alpha=0.7, label='Data')
plt.plot(post_lab, predicted_pre, color='red', label='Linear Regression')

# Add labels and title
plt.title('Linear Least Squares: pre-molt vs post-molt for Lab data')
plt.xlabel('post-molt')
plt.ylabel('pre-molt')
plt.legend()

# Residual plot
plt.subplot(1, 2, 2)
plt.scatter(predicted_pre, residuals_l, color='green', alpha=0.7)

# Add a horizontal line for zero residuals
plt.axhline(0, color='black', linestyle='--', label='Zero Residuals Line')

# Add labels and title
plt.title('Residuals Plot')
plt.xlabel('Predicted pre molt')
plt.ylabel('Residuals')
plt.legend()

# Show the plots
plt.tight_layout()
plt.show()

# Print Pearson's R-squared value
r_squared = r_value**2
print(f"Pearson's R-squared value: {r_squared}")
# Out:
# Pearson's R-squared value: 0.9809989339639518

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis, probplot


# Calculate the skewness and kurtosis of the residuals
treatment_residuals_skewness = skew(residuals_l)
treatment_residuals_kurtosis = kurtosis(residuals_l)

# Print skewness and kurtosis of residuals
print(f"Skewness of Residuals: {treatment_residuals_skewness}")
print(f"Kurtosis of Residuals: {treatment_residuals_kurtosis}")

# Quantile plot (Q-Q plot) of residuals of treatment data
plt.figure(figsize=(8, 6))
probplot(residuals_l, dist="norm", plot=plt)
plt.title('Quantile Plot of Residuals of lab')

# Show the plot
plt.show()
# Out:
# Skewness of Residuals: 1.0124432564966326
# Kurtosis of Residuals: 6.000611992318094

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis, probplot

# Calculate skewness and kurtosis of residuals of output
output_residuals_skewness = skew(residuals_f)
output_residuals_kurtosis = kurtosis(residuals_f)

# Print skewness and kurtosis of residuals
print(f"Skewness of Residuals: {output_residuals_skewness}")
print(f"Kurtosis of Residuals: {output_residuals_kurtosis}")

# Quantile plot (Q-Q plot) of residuals of output
plt.figure(figsize=(8, 6))
probplot(residuals_f, dist="norm", plot=plt)
plt.title("Quantile Plot of Residuals of field")

# Show the plot
plt.show()
# Out:
# Skewness of Residuals: 0.035556233639723565
# Kurtosis of Residuals: 0.9129150626627078

# %%
import numpy as np
from scipy.stats import kstest, anderson, cramervonmises, shapiro

# Various tests for normality of experiment residuals

# Kolmogorov-Smirnov test
ks_statistic, ks_p_value = kstest(residuals_l, 'norm')
print(f"Kolmogorov-Smirnov Test Statistic: {ks_statistic}")
print(f"Kolmogorov-Smirnov P-Value: {ks_p_value}\n")

# Anderson-Darling test
ad_result = anderson(residuals_l, 'norm')
print(f"Anderson-Darling Test Statistic: {ad_result.statistic}")
print(f"Anderson-Darling Critical Values: {ad_result.critical_values}")
print(f"Anderson-Darling Significance Levels: {ad_result.significance_level}\n")

# Cramer-von Mises test
cvm_result = cramervonmises(residuals_l, 'norm')
print(f"Cramer-von Mises Test Statistic: {cvm_result.statistic}")
print(f"Cramer-von Mises P-Value: {cvm_result.pvalue}\n")

# Shapiro-Wilk test
shapiro_statistic, shapiro_p_value = shapiro(residuals_l)
print(f"Shapiro-Wilk Test Statistic: {shapiro_statistic}")
print(f"Shapiro-Wilk P-Value: {shapiro_p_value}")
# Out:
# Kolmogorov-Smirnov Test Statistic: 0.17938389522854037
# Kolmogorov-Smirnov P-Value: 1.234683845305599e-10
#
# Anderson-Darling Test Statistic: 1.883114707153993
# Anderson-Darling Critical Values: [0.57  0.649 0.779 0.908 1.08 ]
# Anderson-Darling Significance Levels: [15.  10.   5.   2.5  1. ]
#
# Cramer-von Mises Test Statistic: 5.446031614852244
# Cramer-von Mises P-Value: 2.5447177698367796e-10
#
# Shapiro-Wilk Test Statistic: 0.9337337952694833
# Shapiro-Wilk P-Value: 1.3760769946888823e-11

# %%
from scipy.stats import kstest, anderson, cramervonmises, shapiro

# Various tests for normality of residuals of experiment data

# Kolmogorov-Smirnov test
ks_statistic, ks_p_value = kstest(residuals_f, 'norm')
print(f"Kolmogorov-Smirnov Test Statistic: {ks_statistic}")
print(f"Kolmogorov-Smirnov P-Value: {ks_p_value}\n")

# Anderson-Darling test
ad_result = anderson(residuals_f, 'norm')
print(f"Anderson-Darling Test Statistic: {ad_result.statistic}")
print(f"Anderson-Darling Critical Values: {ad_result.critical_values}")
print(f"Anderson-Darling Significance Levels: {ad_result.significance_level}\n")

# Cramer-von Mises test
cvm_result = cramervonmises(residuals_f, 'norm')
print(f"Cramer-von Mises Test Statistic: {cvm_result.statistic}")
print(f"Cramer-von Mises P-Value: {cvm_result.pvalue}\n")

# Shapiro-Wilk test
shapiro_statistic, shapiro_p_value = shapiro(residuals_f)
print(f"Shapiro-Wilk Test Statistic: {shapiro_statistic}")
print(f"Shapiro-Wilk P-Value: {shapiro_p_value}")
# Out:
# Kolmogorov-Smirnov Test Statistic: 0.15240979942179145
# Kolmogorov-Smirnov P-Value: 0.01023058835953583
#
# Anderson-Darling Test Statistic: 0.558274122267207
# Anderson-Darling Critical Values: [0.557 0.634 0.761 0.888 1.056]
# Anderson-Darling Significance Levels: [15.  10.   5.   2.5  1. ]
#
# Cramer-von Mises Test Statistic: 1.0376018608285311
# Cramer-von Mises P-Value: 0.0019464859623424813
#
# Shapiro-Wilk Test Statistic: 0.9856511386768899
# Shapiro-Wilk P-Value: 0.2832637209743508

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.stats.diagnostic import het_breuschpagan, het_white

# Load the data from the stored file (mp2 - input.csv)

# Linear regression model (predicting pre-molt size from post-molt size)
X = df[df['Location'] == 'Field'][['Post-molt']]
y = df[df['Location'] == 'Field']['Pre-molt']

# Add a constant term for the intercept
X_with_constant = sm.add_constant(X)

# Fit the OLS (Ordinary Least Squares) model
model = sm.OLS(y, X_with_constant).fit()

# Predictions and residuals
y_pred = model.predict(X_with_constant)
residuals = y - y_pred

# 1. Visual estimation of heteroskedasticity from residuals plot
plt.figure(figsize=(8, 6))
plt.scatter(y_pred, residuals, color='blue', alpha=0.6)
plt.axhline(0, color='red', linestyle='--')
plt.title('Residuals vs Fitted Values for Field data', fontsize=14)
plt.xlabel('Fitted Values (Predicted Pre-Molt Size)', fontsize=12)
plt.ylabel('Residuals', fontsize=12)
plt.grid(True)
plt.show()

# 2. Breusch-Pagan test
# The test requires the residuals and the independent variables (X)
bp_test = het_breuschpagan(residuals, X_with_constant)

# Extract the test statistics
bp_test_statistic, bp_p_value, bp_f_value, bp_f_p_value = bp_test

print(f'Breusch-Pagan Test Statistic: {bp_test_statistic}')
print(f'Breusch-Pagan p-value: {bp_p_value}')

# 3. White test
# The White test uses the same approach as Breusch-Pagan but allows for non-linearities
white_test = het_white(residuals, X_with_constant)

# Extract the test statistics
white_test_statistic, white_p_value, white_f_value, white_f_p_value = white_test

print(f'White Test Statistic: {white_test_statistic}')
print(f'White Test p-value: {white_p_value}')
# Out:
# Breusch-Pagan Test Statistic: 0.21983906475041393
# Breusch-Pagan p-value: 0.6391625703139843
# White Test Statistic: 0.4179916767755486
# White Test p-value: 0.8113986123627703

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.stats.diagnostic import het_breuschpagan, het_white

# Linear regression model (predicting pre-molt size from post-molt size)
X = df[df['Location'] == 'Lab'][['Post-molt']]
y = df[df['Location'] == 'Lab']['Pre-molt']

# Add a constant term for the intercept
X_with_constant = sm.add_constant(X)

# Fit the OLS (Ordinary Least Squares) model
model = sm.OLS(y, X_with_constant).fit()

# Predictions and residuals
y_pred = model.predict(X_with_constant)
residuals = y - y_pred

# 1. Visual estimation of heteroskedasticity from residuals plot
plt.figure(figsize=(8, 6))
plt.scatter(y_pred, residuals, color='blue', alpha=0.6)
plt.axhline(0, color='red', linestyle='--')
plt.title('Residuals vs Fitted Values for Lab data', fontsize=14)
plt.xlabel('Fitted Values (Predicted Pre-Molt Size)', fontsize=12)
plt.ylabel('Residuals', fontsize=12)
plt.grid(True)
plt.show()

# 2. Breusch-Pagan test
# The test requires the residuals and the independent variables (X)
bp_test = het_breuschpagan(residuals, X_with_constant)

# Extract the test statistics
bp_test_statistic, bp_p_value, bp_f_value, bp_f_p_value = bp_test

print(f'Breusch-Pagan Test Statistic: {bp_test_statistic}')
print(f'Breusch-Pagan p-value: {bp_p_value}')

# 3. White test
# The White test uses the same approach as Breusch-Pagan but allows for non-linearities
white_test = het_white(residuals, X_with_constant)

# Extract the test statistics
white_test_statistic, white_p_value, white_f_value, white_f_p_value = white_test

print(f'White Test Statistic: {white_test_statistic}')
print(f'White Test p-value: {white_p_value}')
# Out:
# Breusch-Pagan Test Statistic: 79.96815660964577
# Breusch-Pagan p-value: 3.804926341825463e-19
# White Test Statistic: 194.13903288206737
# White Test p-value: 6.970190513180402e-43

# %%
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt

field_data =df[df['Location'] == 'Field']
lab_data =df[df['Location'] == 'Lab']


# Analysis of potentially different Linear models for Lab versus Field crabs

# Fit Linear model for Field crabs
field_X = sm.add_constant(field_data['Post-molt'])  # Add constant for intercept
field_model = sm.OLS(field_data['Pre-molt'], field_X)  # OLS regression
field_results = field_model.fit()  # Fit the model

# Fit Linear model for Lab crabs
lab_X = sm.add_constant(lab_data['Post-molt'])  # Add constant for intercept
lab_model = sm.OLS(lab_data['Pre-molt'], lab_X)  # OLS regression
lab_results = lab_model.fit()  # Fit the model

# Scatterplot and Regression Line for Field Crabs
plt.figure(figsize=(12, 6))

# Scatterplot for Field Crabs
sns.scatterplot(x='Post-molt', y='Pre-molt', data=field_data, label='Field Crabs')
# Regression line for Field Crabs
sns.lineplot(x=field_data['Post-molt'], y=field_results.predict(field_X), color='blue')

# Scatterplot and Regression Line for Lab Crabs
sns.scatterplot(x='Post-molt', y='Pre-molt', data=lab_data, label='Lab Crabs')
# Regression line for Lab Crabs
sns.lineplot(x=lab_data['Post-molt'], y=lab_results.predict(lab_X), color='orange')

# Add titles and labels
plt.title("Linear Models for Lab vs. Field Crabs")
plt.xlabel('Post-molt Sizes')
plt.ylabel('Pre-molt Sizes')
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score
import statsmodels.api as sm

# Utilizing cross-validation to estimate prediction accuracy of Linear models
field_post_molt_sizes =df[df['Location'] == 'Field']['Post-molt']
field_pre_molt_sizes =df[df['Location'] == 'Field']['Pre-molt']
lab_post_molt_sizes =df[df['Location'] == 'Lab']['Post-molt']
lab_pre_molt_sizes =df[df['Location'] == 'Lab']['Pre-molt']

# Combine the data for Lab and Field crabs
field_post_molt_data = np.array(field_post_molt_sizes)
lab_post_molt_data = np.array(lab_post_molt_sizes)

all_post_molt_sizes = np.concatenate([field_post_molt_data, lab_post_molt_data])
all_pre_molt_sizes = np.concatenate([field_pre_molt_sizes, lab_pre_molt_sizes])

# Create a DataFrame for combined data
all_locations = ['Field'] * len(field_post_molt_sizes) + ['Lab'] * len(lab_post_molt_sizes)
combined_data = pd.DataFrame({
    'Location': all_locations,
    'Post-molt': all_post_molt_sizes,
    'Pre-molt': all_pre_molt_sizes
})

# Perform 5-fold cross-validation for both Lab and Field crabs
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Initialize arrays to store predicted values and true labels
predicted_values = np.array([])
true_labels = np.array([])

# Loop through each fold
for train_idx, test_idx in kfold.split(combined_data):

    # Split data into training and testing sets for each fold
    train_data = combined_data.iloc[train_idx]
    test_data = combined_data.iloc[test_idx]

    # Fit the model on training data (use sm.OLS here)
    model = sm.OLS(train_data['Pre-molt'], sm.add_constant(train_data['Post-molt']))
    results = model.fit()

    # Predict on the testing data
    predictions = results.predict(sm.add_constant(test_data['Post-molt']))

    # Store the predicted values and true labels
    predicted_values = np.concatenate((predicted_values, predictions))
    true_labels = np.concatenate((true_labels, test_data['Pre-molt'].values))

# Calculate R-squared manually
r_squared = r2_score(true_labels, predicted_values)

print("Cross-validated R-squared:", r_squared)
# Out:
# Cross-validated R-squared: 0.9799396959619163
